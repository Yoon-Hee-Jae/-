# %%
import pandas as pd

# %%
df = pd.read_excel('/content/지역 유통 (판매) 데이터_ 물류센터-소매점 판매 데이터(필수).xlsx', sheet_name='데이터')
df.head()
# Out:
#          판매일  구분   우편번호  판매수량 옵션코드        규격  입수        상품 바코드  \
# 0 2021-01-04  매출  37542     4   EA    100g*1   1  8.801007e+12
# 1 2021-01-04  매출  37542     2   BX       12입  12  1.880104e+13
# 2 2021-01-04  매출  37542     1   EA        1입   1  8.809199e+12
# 3 2021-01-04  매출  37542     1   EA  50g*16*1   1  8.801077e+12
# 4 2021-01-04  매출  37542     3   EA       10입   1  8.801045e+12
#
#                  상품명  Unnamed: 9  Unnamed: 10
# 0      다시다)쇠골드명품100g         NaN          NaN
# 1     사조]해표식용유<1.8L>         NaN          NaN
# 2  젓가락]키친센스 나무<250p>         NaN          NaN
# 3       소세지 천하장사800g         NaN          NaN
# 4   오뚜기]옛날자른당면<1kg >         NaN          NaN

# %%
# 옵션코드 = EA 최소단위 / CS 묶음단위 / BX 박스단위
# 입수 = 해당 옵션코드에 상품이 들어있는 EA 수량

# %%
print(min(df['판매일']))
print(max(df['판매일']))
# Out:
# 2021-01-04 00:00:00
# 2022-07-01 00:00:00

# %%
df['구분'].value_counts()
# Out:
# 매출    508839
# 반품     13156
# Name: 구분, dtype: int64

# %%
print(df['상품명'].value_counts())
print('상품 개수 = ',df['상품명'].nunique())
# Out:
# 가야산천년수<2L*6>                5942
# 가야산천년수<500ml*20>            3723
# 삼다수2L                       2813
# 농심]안성탕면 멀티<40>              2774
# 육개장 사발 6入 XX                2672
#                             ...
# 쌍-기능성 탁텔사/점박이 장갑 (대,중,소)       1
# 건전지]백셀낱개<C>                    1
# 헤드셋-대진 TGH-DJ1XXXXX            1
# 숯 아래타 2입XXX                    1
# 가스렌지 투버너                       1
# Name: 상품명, Length: 7500, dtype: int64
# 상품 개수 =  7500

# %%
# 맞춰야 하는 답안
#    상품명              바코드
# 가야산천년수<2L*6> 8809274240219
#    삼다수2L        8808244208044
#  박카스F 120ml     8806011615422
# 레쓰비<175ml*30>   68801056290308
# 코카콜라<1.5*12>   8801094012403
# 농심]안성탕면 멀티<40> 8801043014793
# 농심]신라면 멀티<40>  8801043014847
# 농심]짜파게티 멀티<40> 8801043015271
# 오뚜기]진라면매운멀티<120g> 18801045522286
# 농심]너구리 얼큰멀티<40> 8801043015028

# %%
# 10개 품목을 다른 데이트프레임에 나누어서 저장
df1 = df[df['상품 바코드'] == 8809274240219].copy().reset_index(drop=True)
df2 = df[df['상품 바코드'] == 8808244208044].copy().reset_index(drop=True)
df3 = df[df['상품 바코드'] == 8806011615422].copy().reset_index(drop=True)
df4 = df[df['상품 바코드'] == 68801056290308].copy().reset_index(drop=True)
df5 = df[df['상품 바코드'] == 8801094012403].copy().reset_index(drop=True)
df6 = df[df['상품 바코드'] == 8801043014793].copy().reset_index(drop=True)
df7 = df[df['상품 바코드'] == 8801043014847].copy().reset_index(drop=True)
df8 = df[df['상품 바코드'] == 8801043015271].copy().reset_index(drop=True)
df9 = df[df['상품 바코드'] == 18801045522286].copy().reset_index(drop=True)
df10 = df[df['상품 바코드'] == 8801043015028].copy().reset_index(drop=True)

# %%
df1
# Out:
#             판매일  구분     우편번호  판매수량 옵션코드  규격  입수        상품 바코드           상품명  \
# 0    2021-01-04  매출    37575     3   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 1    2021-01-04  매출    37611    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 2    2021-01-04  매출    37741     5   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 3    2021-01-04  매출  377-65     15   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 4    2021-01-04  매출    37767   160   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# ...         ...  ..      ...   ...  ...  ..  ..           ...           ...
# 5936 2022-07-01  매출    37928    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5937 2022-07-01  매출    37930     3   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5938 2022-07-01  매출    38004    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5939 2022-07-01  매출    38039    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5940 2022-07-01  매출    37924     8   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
#
#       Unnamed: 9  Unnamed: 10
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ...          ...          ...
# 5936         NaN          NaN
# 5937         NaN          NaN
# 5938         NaN          NaN
# 5939         NaN          NaN
# 5940         NaN          NaN
#
# [5941 rows x 11 columns]

# %%
df1.iloc[30:50,:]
# 반품은 상품이 팔린게 그대로 다시 반품되는 거 확인
# Out:
#           판매일  구분   우편번호  판매수량 옵션코드  규격  입수        상품 바코드           상품명  \
# 30 2021-01-06  매출  37714     5   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 31 2021-01-06  매출  37728     5   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 32 2021-01-06  매출  37733     6   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 33 2021-01-06  매출  37786     5   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 34 2021-01-06  매출  37850    25   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 35 2021-01-06  매출  37917     5   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 36 2021-01-06  매출  37926    12   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 37 2021-01-06  매출  38178    18   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 38 2021-01-06  반품  37926    12   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 39 2021-01-07  매출  37559    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 40 2021-01-07  매출  37650    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 41 2021-01-07  매출  37700    20   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 42 2021-01-07  매출  37772    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 43 2021-01-07  매출  37818    20   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 44 2021-01-07  매출  37840    20   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 45 2021-01-07  매출  37867    50   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 46 2021-01-07  매출  37869    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 47 2021-01-07  매출  37935    20   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 48 2021-01-08  매출  37655    13   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 49 2021-01-08  매출  37733    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
#
#     Unnamed: 9  Unnamed: 10
# 30         NaN          NaN
# 31         NaN          NaN
# 32         NaN          NaN
# 33         NaN          NaN
# 34         NaN          NaN
# 35         NaN          NaN
# 36         NaN          NaN
# 37         NaN          NaN
# 38         NaN          NaN
# 39         NaN          NaN
# 40         NaN          NaN
# 41         NaN          NaN
# 42         NaN          NaN
# 43         NaN          NaN
# 44         NaN          NaN
# 45         NaN          NaN
# 46         NaN          NaN
# 47         NaN          NaN
# 48         NaN          NaN
# 49         NaN          NaN

# %%
# 날짜 저장 형식 확인
type(df1['판매일'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# 날짜 별로 판매수량 더하기
df1_true = df1[df1['구분']=='매출'][['판매일','판매수량']]
df1_true

df1_false = df1[df1['구분']=='반품'][['판매일','판매수량']]
df1_false
# Out:
#             판매일  판매수량
# 38   2021-01-06    12
# 225  2021-01-26    40
# 234  2021-01-27    80
# 646  2021-03-10     5
# 875  2021-03-31     5
# 1326 2021-05-07     5
# 1620 2021-06-02     1
# 2576 2021-08-13     5
# 3820 2021-12-15     5
# 4241 2022-01-25     1
# 4470 2022-02-18     4

# %%
# 일별 매출 총합
df_sum_by_date_0 = df1_true.groupby('판매일').sum()
df_sum_by_date_0 = df_sum_by_date_0.reset_index()

df_sum_by_date_0
# Out:
#            판매일  판매수량
# 0   2021-01-04   258
# 1   2021-01-05   103
# 2   2021-01-06   102
# 3   2021-01-07   170
# 4   2021-01-08   179
# ..         ...   ...
# 375 2022-06-27   171
# 376 2022-06-28    59
# 377 2022-06-29   504
# 378 2022-06-30   114
# 379 2022-07-01   418
#
# [380 rows x 2 columns]

# %%
# 일별 반품 총합
df_sum_by_date_1 = df1_false.groupby('판매일').sum()
df_sum_by_date_1 = df_sum_by_date_1.reset_index()

df_sum_by_date_1
# Out:
#           판매일  판매수량
# 0  2021-01-06    12
# 1  2021-01-26    40
# 2  2021-01-27    80
# 3  2021-03-10     5
# 4  2021-03-31     5
# 5  2021-05-07     5
# 6  2021-06-02     1
# 7  2021-08-13     5
# 8  2021-12-15     5
# 9  2022-01-25     1
# 10 2022-02-18     4

# %%
# 반품/매출 데이터프레임 합치기
merged_df1 = pd.merge(df_sum_by_date_0, df_sum_by_date_1, on='판매일', suffixes=('_df0', '_df1'), how='left')
merged_df1
# Out:
#            판매일  판매수량_df0  판매수량_df1
# 0   2021-01-04       258       NaN
# 1   2021-01-05       103       NaN
# 2   2021-01-06       102      12.0
# 3   2021-01-07       170       NaN
# 4   2021-01-08       179       NaN
# ..         ...       ...       ...
# 375 2022-06-27       171       NaN
# 376 2022-06-28        59       NaN
# 377 2022-06-29       504       NaN
# 378 2022-06-30       114       NaN
# 379 2022-07-01       418       NaN
#
# [380 rows x 3 columns]

# %%
# 비어있는 값 채워줘야함
# 숫자 - null = null
merged_df1.fillna(0,inplace=True)

# %%
# 최종 판매수량 구하기
merged_df1['최종 판매수량'] = merged_df1['판매수량_df0'] - merged_df1['판매수량_df1']
merged_df1
# Out:
#            판매일  판매수량_df0  판매수량_df1  최종 판매수량
# 0   2021-01-04       258       0.0    258.0
# 1   2021-01-05       103       0.0    103.0
# 2   2021-01-06       102      12.0     90.0
# 3   2021-01-07       170       0.0    170.0
# 4   2021-01-08       179       0.0    179.0
# ..         ...       ...       ...      ...
# 375 2022-06-27       171       0.0    171.0
# 376 2022-06-28        59       0.0     59.0
# 377 2022-06-29       504       0.0    504.0
# 378 2022-06-30       114       0.0    114.0
# 379 2022-07-01       418       0.0    418.0
#
# [380 rows x 4 columns]

# %%
# 2021년 2022년 분리
df1_2021 = merged_df1[merged_df1['판매일'].dt.year == 2021].reset_index(drop=True)
df1_2022 = merged_df1[merged_df1['판매일'].dt.year == 2022].reset_index(drop=True)

# %%
df1_2021
# Out:
#            판매일  판매수량_df0  판매수량_df1  최종 판매수량
# 0   2021-01-04       258       0.0    258.0
# 1   2021-01-05       103       0.0    103.0
# 2   2021-01-06       102      12.0     90.0
# 3   2021-01-07       170       0.0    170.0
# 4   2021-01-08       179       0.0    179.0
# ..         ...       ...       ...      ...
# 251 2021-12-27        91       0.0     91.0
# 252 2021-12-28       243       0.0    243.0
# 253 2021-12-29       135       0.0    135.0
# 254 2021-12-30       182       0.0    182.0
# 255 2021-12-31       218       0.0    218.0
#
# [256 rows x 4 columns]

# %%
df1_2021.keys()
# Out:
# Index(['판매일', '판매수량_df0', '판매수량_df1', '최종 판매수량'], dtype='object')

# %%
# 2021년 최종 판매량 그래프

import matplotlib.pyplot as plt
# 그래프 초기화
plt.figure()

dates = df1_2021['판매일']
sales_quantity = df1_2021['최종 판매수량']

# 그래프 그리기 (점을 없애고 곡선 형태로)
plt.figure(figsize=(10, 6))  # 그래프 크기 설정
plt.plot(dates, sales_quantity, linestyle='-')  # 선 그래프 그리기
plt.xlabel('날짜')  # x축 레이블 설정
plt.ylabel('판매 수량')  # y축 레이블 설정
plt.title('날짜별 판매 수량')  # 그래프 제목 설정
plt.xticks(df1_2021['판매일'][::1]) # 하루단위
plt.xticks(rotation=45)  # x축 레이블 회전
plt.tight_layout()  # 그래프 레이아웃 조정
plt.show()  # 그래프 표시
# Out:
# <ipython-input-21-51223e3d2a8e>:18: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-21-51223e3d2a8e>:18: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-21-51223e3d2a8e>:18: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-21-51223e3d2a8e>:18: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-21-51223e3d2a8e>:18: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-21-51223e3d2a8e>:18: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-21-51223e3d2a8e>:18: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 2021년 최종 판매량 그래프
# 그래프 초기화
plt.figure()

dates = df1_2022['판매일']
sales_quantity = df1_2022['최종 판매수량']

# 그래프 그리기 (점을 없애고 곡선 형태로)
plt.figure(figsize=(10, 6))  # 그래프 크기 설정
plt.plot(dates, sales_quantity, linestyle='-')  # 선 그래프 그리기
plt.xlabel('날짜')  # x축 레이블 설정
plt.ylabel('판매 수량')  # y축 레이블 설정
plt.title('날짜별 판매 수량')  # 그래프 제목 설정
plt.xticks(df1_2022['판매일'][::1]) # 하루단위
plt.xticks(rotation=45)  # x축 레이블 회전
plt.tight_layout()  # 그래프 레이아웃 조정
plt.show()  # 그래프 표시
# Out:
# <ipython-input-22-80e919dd5de8>:16: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-22-80e919dd5de8>:16: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-22-80e919dd5de8>:16: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-22-80e919dd5de8>:16: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-22-80e919dd5de8>:16: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-22-80e919dd5de8>:16: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-22-80e919dd5de8>:16: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정

# %%
# 보기 애매해서 우선 각 월별로 다시 그래프 그려보기
df1_2021_1 = df1_2021[df1_2021['판매일'].dt.month == 1].reset_index(drop=True)
df1_2021_1
# Out:
#           판매일  판매수량_df0  판매수량_df1  최종 판매수량
# 0  2021-01-04       258       0.0    258.0
# 1  2021-01-05       103       0.0    103.0
# 2  2021-01-06       102      12.0     90.0
# 3  2021-01-07       170       0.0    170.0
# 4  2021-01-08       179       0.0    179.0
# 5  2021-01-11       234       0.0    234.0
# 6  2021-01-12       303       0.0    303.0
# 7  2021-01-13       143       0.0    143.0
# 8  2021-01-14       234       0.0    234.0
# 9  2021-01-15       133       0.0    133.0
# 10 2021-01-18       169       0.0    169.0
# 11 2021-01-19       144       0.0    144.0
# 12 2021-01-20        41       0.0     41.0
# 13 2021-01-21       297       0.0    297.0
# 14 2021-01-22        67       0.0     67.0
# 15 2021-01-25       180       0.0    180.0
# 16 2021-01-26        97      40.0     57.0
# 17 2021-01-27       155      80.0     75.0
# 18 2021-01-28       260       0.0    260.0
# 19 2021-01-29       144       0.0    144.0

# %%
# 2021년 1월 최종 판매량 그래프
# 그래프 초기화
plt.figure()

dates = df1_2021_1['판매일']
sales_quantity = df1_2021_1['최종 판매수량']

# 그래프 그리기 (점을 없애고 곡선 형태로)
plt.figure(figsize=(10, 6))  # 그래프 크기 설정
plt.plot(dates, sales_quantity, linestyle='-')  # 선 그래프 그리기
plt.xlabel('날짜')  # x축 레이블 설정
plt.ylabel('판매 수량')  # y축 레이블 설정
plt.title('날짜별 판매 수량')  # 그래프 제목 설정
plt.xticks(df1_2021_1['판매일'][::1]) # 하루단위
plt.xticks(rotation=45)  # x축 레이블 회전
plt.tight_layout()  # 그래프 레이아웃 조정
plt.show()  # 그래프 표시
# Out:
# <ipython-input-24-852925a4e78b>:16: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-24-852925a4e78b>:16: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-24-852925a4e78b>:16: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-24-852925a4e78b>:16: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-24-852925a4e78b>:16: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-24-852925a4e78b>:16: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# <ipython-input-24-852925a4e78b>:16: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.tight_layout()  # 그래프 레이아웃 조정
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df1_2021
# Out:
#            판매일  판매수량_df0  판매수량_df1  최종 판매수량
# 0   2021-01-04       258       0.0    258.0
# 1   2021-01-05       103       0.0    103.0
# 2   2021-01-06       102      12.0     90.0
# 3   2021-01-07       170       0.0    170.0
# 4   2021-01-08       179       0.0    179.0
# ..         ...       ...       ...      ...
# 251 2021-12-27        91       0.0     91.0
# 252 2021-12-28       243       0.0    243.0
# 253 2021-12-29       135       0.0    135.0
# 254 2021-12-30       182       0.0    182.0
# 255 2021-12-31       218       0.0    218.0
#
# [256 rows x 4 columns]

# %%
# lstm으로 예측

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
# 데이터 시각화
df1_2021['최종 판매수량'].plot(figsize=(10, 6))
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# 데이터 스케일링
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df1_2021['최종 판매수량'].values.reshape(-1, 1))

# 훈련 데이터와 타겟 데이터 분리
look_back = 7  # 7일 전 데이터를 기반으로 다음날을 예측
X, y = [], []
for i in range(len(scaled_data) - look_back):
    X.append(scaled_data[i:i+look_back])
    y.append(scaled_data[i+look_back])

X = np.array(X)
y = np.array(y)

# 훈련 데이터와 검증 데이터 분할
train_size = int(0.8 * len(X))
X_train, X_valid = X[:train_size], X[train_size:]
y_train, y_valid = y[:train_size], y[train_size:]

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(look_back, 1)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_valid, y_valid), verbose=1)
# Out:
# Epoch 1/50
# 13/13 [==============================] - 2s 36ms/step - loss: 0.0413 - val_loss: 0.0086
# Epoch 2/50
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0170 - val_loss: 0.0109
# Epoch 3/50
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0166 - val_loss: 0.0089
# Epoch 4/50
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0156 - val_loss: 0.0073
# Epoch 5/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0154 - val_loss: 0.0081
# Epoch 6/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0084
# Epoch 7/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0153 - val_loss: 0.0079
# Epoch 8/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0154 - val_loss: 0.0079
# Epoch 9/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0153 - val_loss: 0.0081
# Epoch 10/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0153 - val_loss: 0.0078
# Epoch 11/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0153 - val_loss: 0.0084
# Epoch 12/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0153 - val_loss: 0.0079
# Epoch 13/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0155 - val_loss: 0.0080
# Epoch 14/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0153 - val_loss: 0.0088
# Epoch 15/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0154 - val_loss: 0.0082
# Epoch 16/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0155 - val_loss: 0.0077
# Epoch 17/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0154 - val_loss: 0.0087
# Epoch 18/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0152 - val_loss: 0.0080
# Epoch 19/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0153 - val_loss: 0.0079
# Epoch 20/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0153 - val_loss: 0.0084
# Epoch 21/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0153 - val_loss: 0.0080
# Epoch 22/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0085
# Epoch 23/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0153 - val_loss: 0.0080
# Epoch 24/50
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0155 - val_loss: 0.0076
# Epoch 25/50
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0153 - val_loss: 0.0084
# Epoch 26/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0154 - val_loss: 0.0082
# Epoch 27/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0153 - val_loss: 0.0082
# Epoch 28/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0157 - val_loss: 0.0084
# Epoch 29/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0155 - val_loss: 0.0074
# Epoch 30/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0155 - val_loss: 0.0092
# Epoch 31/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0153 - val_loss: 0.0077
# Epoch 32/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0155 - val_loss: 0.0084
# Epoch 33/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0154 - val_loss: 0.0080
# Epoch 34/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0153 - val_loss: 0.0083
# Epoch 35/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.0085
# Epoch 36/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0153 - val_loss: 0.0076
# Epoch 37/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0154 - val_loss: 0.0080
# Epoch 38/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0080
# Epoch 39/50
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0081
# Epoch 40/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0152 - val_loss: 0.0078
# Epoch 41/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0151 - val_loss: 0.0084
# Epoch 42/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0153 - val_loss: 0.0080
# Epoch 43/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0152 - val_loss: 0.0085
# Epoch 44/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0153 - val_loss: 0.0083
# Epoch 45/50
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0153 - val_loss: 0.0080
# Epoch 46/50
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0151 - val_loss: 0.0081
# Epoch 47/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0153 - val_loss: 0.0082
# Epoch 48/50
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0151 - val_loss: 0.0076
# Epoch 49/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0152 - val_loss: 0.0079
# Epoch 50/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0151 - val_loss: 0.0085

# %%
# 검증 데이터에 대한 예측
y_pred = model.predict(X_valid)

# 예측 결과 역스케일링
y_pred = scaler.inverse_transform(y_pred)
y_valid = scaler.inverse_transform(y_valid)

# 예측 결과 시각화
plt.figure(figsize=(10, 6))
plt.plot(df1_2021['최종 판매수량'].index[train_size + look_back:], y_valid, label='Actual')
plt.plot(df1_2021['최종 판매수량'].index[train_size + look_back:], y_pred, label='Predicted')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
# 판매수량 말고도 다른 변수 추가 필요함
# ex) 주말여부/

# %%
A = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
for i in A:
 print(i)
# Out:
#             판매일  구분     우편번호  판매수량 옵션코드  규격  입수        상품 바코드           상품명  \
# 0    2021-01-04  매출    37575     3   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 1    2021-01-04  매출    37611    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 2    2021-01-04  매출    37741     5   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 3    2021-01-04  매출  377-65     15   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 4    2021-01-04  매출    37767   160   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# ...         ...  ..      ...   ...  ...  ..  ..           ...           ...
# 5936 2022-07-01  매출    37928    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5937 2022-07-01  매출    37930     3   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5938 2022-07-01  매출    38004    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5939 2022-07-01  매출    38039    10   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
# 5940 2022-07-01  매출    37924     8   CS  6입   6  8.809274e+12  가야산천년수<2L*6>
#
#       Unnamed: 9  Unnamed: 10
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ...          ...          ...
# 5936         NaN          NaN
# 5937         NaN          NaN
# 5938         NaN          NaN
# 5939         NaN          NaN
# 5940         NaN          NaN
#
# [5941 rows x 11 columns]
#             판매일  구분   우편번호  판매수량 옵션코드    규격  입수        상품 바코드    상품명  \
# 0    2021-01-04  매출  37575     5   CS  2L*6   6  8.808244e+12  삼다수2L
# 1    2021-01-04  매출  37632    10   CS  2L*6   6  8.808244e+12  삼다수2L
# 2    2021-01-04  매출  37661    10   CS  2L*6   6  8.808244e+12  삼다수2L
# 3    2021-01-04  매출  37692    10   CS  2L*6   6  8.808244e+12  삼다수2L
# 4    2021-01-04  매출  37782     3   CS  2L*6   6  8.808244e+12  삼다수2L
# ...         ...  ..    ...   ...  ...   ...  ..           ...    ...
# 2720 2022-07-01  매출  37806     5   CS  2L*6   6  8.808244e+12  삼다수2L
# 2721 2022-07-01  매출  37853     5   CS  2L*6   6  8.808244e+12  삼다수2L
# 2722 2022-07-01  매출  37935     5   CS  2L*6   6  8.808244e+12  삼다수2L
# 2723 2022-07-01  매출  38039     3   CS  2L*6   6  8.808244e+12  삼다수2L
# 2724 2022-07-01  매출  37924     3   CS  2L*6   6  8.808244e+12  삼다수2L
#
#       Unnamed: 9  Unnamed: 10
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ...          ...          ...
# 2720         NaN          NaN
# 2721         NaN          NaN
# 2722         NaN          NaN
# 2723         NaN          NaN
# 2724         NaN          NaN
#
# [2725 rows x 11 columns]
#            판매일  구분   우편번호  판매수량 옵션코드         규격  입수        상품 바코드         상품명  \
# 0   2021-01-04  매출  37890     4   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 1   2021-01-05  매출  37650    10   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 2   2021-01-05  매출  37803     4   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 3   2021-01-07  매출  37840    20   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 4   2021-01-08  매출  37575     4   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# ..         ...  ..    ...   ...  ...        ...  ..           ...         ...
# 722 2022-06-30  매출  37608    10   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 723 2022-06-30  매출  50246     4   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 724 2022-07-01  매출  37632     5   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 725 2022-07-01  매출  37803     2   CS  120ml*100  10  8.806012e+12  박카스F 120ml
# 726 2022-07-01  매출  37933    30   CS  120ml*100  10  8.806012e+12  박카스F 120ml
#
#      Unnamed: 9  Unnamed: 10
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 722         NaN          NaN
# 723         NaN          NaN
# 724         NaN          NaN
# 725         NaN          NaN
# 726         NaN          NaN
#
# [727 rows x 11 columns]
#             판매일  구분   우편번호  판매수량 옵션코드        규격  입수        상품 바코드  \
# 0    2021-01-04  매출  37575     1   BX  175ml*30  30  6.880106e+13
# 1    2021-01-04  매출   3766     2   BX  175ml*30  30  6.880106e+13
# 2    2021-01-04  매출  37775     1   BX  175ml*30  30  6.880106e+13
# 3    2021-01-04  매출  37787     3   BX  175ml*30  30  6.880106e+13
# 4    2021-01-04  매출  37831     2   BX  175ml*30  30  6.880106e+13
# ...         ...  ..    ...   ...  ...       ...  ..           ...
# 1486 2022-06-29  매출  37788    10   BX  175ml*30  30  6.880106e+13
# 1487 2022-06-30  매출  37926     7   BX  175ml*30  30  6.880106e+13
# 1488 2022-07-01  매출  37811    10   BX  175ml*30  30  6.880106e+13
# 1489 2022-07-01  매출  37816     1   BX  175ml*30  30  6.880106e+13
# 1490 2022-07-01  매출  37935     5   BX  175ml*30  30  6.880106e+13
#
#                 상품명  Unnamed: 9  Unnamed: 10
# 0     레쓰비<175ml*30>         NaN          NaN
# 1     레쓰비<175ml*30>         NaN          NaN
# 2     레쓰비<175ml*30>         NaN          NaN
# 3     레쓰비<175ml*30>         NaN          NaN
# 4     레쓰비<175ml*30>         NaN          NaN
# ...             ...         ...          ...
# 1486  레쓰비<175ml*30>         NaN          NaN
# 1487  레쓰비<175ml*30>         NaN          NaN
# 1488  레쓰비<175ml*30>         NaN          NaN
# 1489  레쓰비<175ml*30>         NaN          NaN
# 1490  레쓰비<175ml*30>         NaN          NaN
#
# [1491 rows x 11 columns]
#             판매일  구분   우편번호  판매수량 옵션코드       규격  입수        상품 바코드  \
# 0    2021-01-04  매출  37907    36   EA  1.5L*12   1  8.801094e+12
# 1    2021-01-05  매출  37746    12   EA  1.5L*12   1  8.801094e+12
# 2    2021-01-06  매출  37606    12   EA  1.5L*12   1  8.801094e+12
# 3    2021-01-07  매출  37588    12   EA  1.5L*12   1  8.801094e+12
# 4    2021-01-07  매출  37676    12   EA  1.5L*12   1  8.801094e+12
# ...         ...  ..    ...   ...  ...      ...  ..           ...
# 1259 2022-07-01  매출  37836    12   EA  1.5L*12   1  8.801094e+12
# 1260 2022-07-01  매출  37853    12   EA  1.5L*12   1  8.801094e+12
# 1261 2022-07-01  매출  37890    12   EA  1.5L*12   1  8.801094e+12
# 1262 2022-07-01  매출  37907    12   EA  1.5L*12   1  8.801094e+12
# 1263 2022-07-01  매출  37924    12   EA  1.5L*12   1  8.801094e+12
#
#                상품명  Unnamed: 9  Unnamed: 10
# 0     코카콜라<1.5*12>         NaN          NaN
# 1     코카콜라<1.5*12>         NaN          NaN
# 2     코카콜라<1.5*12>         NaN          NaN
# 3     코카콜라<1.5*12>         NaN          NaN
# 4     코카콜라<1.5*12>         NaN          NaN
# ...            ...         ...          ...
# 1259  코카콜라<1.5*12>         NaN          NaN
# 1260  코카콜라<1.5*12>         NaN          NaN
# 1261  코카콜라<1.5*12>         NaN          NaN
# 1262  코카콜라<1.5*12>         NaN          NaN
# 1263  코카콜라<1.5*12>         NaN          NaN
#
# [1264 rows x 11 columns]
#             판매일  구분   우편번호  판매수량 옵션코드       규격  입수        상품 바코드  \
# 0    2021-01-04  매출  37575     1   BX  125g*40  40  8.801043e+12
# 1    2021-01-04  매출  37581     1   BX  125g*40  40  8.801043e+12
# 2    2021-01-04  매출  37588     1   BX  125g*40  40  8.801043e+12
# 3    2021-01-04  매출  37633     1   BX  125g*40  40  8.801043e+12
# 4    2021-01-04  매출  37646     1   BX  125g*40  40  8.801043e+12
# ...         ...  ..    ...   ...  ...      ...  ..           ...
# 2767 2022-07-01  매출  37853     1   BX  125g*40  40  8.801043e+12
# 2768 2022-07-01  매출  37890     1   BX  125g*40  40  8.801043e+12
# 2769 2022-07-01  매출  37925     3   BX  125g*40  40  8.801043e+12
# 2770 2022-07-01  매출  37931     5   BX  125g*40  40  8.801043e+12
# 2771 2022-07-01  매출  38002     2   BX  125g*40  40  8.801043e+12
#
#                  상품명  Unnamed: 9  Unnamed: 10
# 0     농심]안성탕면 멀티<40>         NaN          NaN
# 1     농심]안성탕면 멀티<40>         NaN          NaN
# 2     농심]안성탕면 멀티<40>         NaN          NaN
# 3     농심]안성탕면 멀티<40>         NaN          NaN
# 4     농심]안성탕면 멀티<40>         NaN          NaN
# ...              ...         ...          ...
# 2767  농심]안성탕면 멀티<40>         NaN          NaN
# 2768  농심]안성탕면 멀티<40>         NaN          NaN
# 2769  농심]안성탕면 멀티<40>         NaN          NaN
# 2770  농심]안성탕면 멀티<40>         NaN          NaN
# 2771  농심]안성탕면 멀티<40>         NaN          NaN
#
# [2772 rows x 11 columns]
#             판매일  구분     우편번호  판매수량 옵션코드       규격  입수        상품 바코드  \
# 0    2021-01-04  매출    37544     1   BX  120g*40  40  8.801043e+12
# 1    2021-01-04  매출    37575     1   BX  120g*40  40  8.801043e+12
# 2    2021-01-04  매출    37661     1   BX  120g*40  40  8.801043e+12
# 3    2021-01-04  매출    37676     2   BX  120g*40  40  8.801043e+12
# 4    2021-01-04  매출    37733     1   BX  120g*40  40  8.801043e+12
# ...         ...  ..      ...   ...  ...      ...  ..           ...
# 2263 2022-07-01  매출    37890     1   BX  120g*40  40  8.801043e+12
# 2264 2022-07-01  매출    37899     2   BX  120g*40  40  8.801043e+12
# 2265 2022-07-01  매출    37925     2   BX  120g*40  40  8.801043e+12
# 2266 2022-07-01  매출  379-26      1   BX  120g*40  40  8.801043e+12
# 2267 2022-07-01  매출    37931     3   BX  120g*40  40  8.801043e+12
#
#                 상품명  Unnamed: 9  Unnamed: 10
# 0     농심]신라면 멀티<40>         NaN          NaN
# 1     농심]신라면 멀티<40>         NaN          NaN
# 2     농심]신라면 멀티<40>         NaN          NaN
# 3     농심]신라면 멀티<40>         NaN          NaN
# 4     농심]신라면 멀티<40>         NaN          NaN
# ...             ...         ...          ...
# 2263  농심]신라면 멀티<40>         NaN          NaN
# 2264  농심]신라면 멀티<40>         NaN          NaN
# 2265  농심]신라면 멀티<40>         NaN          NaN
# 2266  농심]신라면 멀티<40>         NaN          NaN
# 2267  농심]신라면 멀티<40>         NaN          NaN
#
# [2268 rows x 11 columns]
#             판매일  구분   우편번호  판매수량 옵션코드        규격  입수        상품 바코드  \
# 0    2021-01-04  매출  37575     1   BX  140g*5*8  40  8.801043e+12
# 1    2021-01-04  매출  37826     1   BX  140g*5*8  40  8.801043e+12
# 2    2021-01-04  매출  37830     1   BX  140g*5*8  40  8.801043e+12
# 3    2021-01-04  매출  37836     1   BX  140g*5*8  40  8.801043e+12
# 4    2021-01-04  매출  37888     1   BX  140g*5*8  40  8.801043e+12
# ...         ...  ..    ...   ...  ...       ...  ..           ...
# 1864 2022-07-01  매출  37692     1   BX  140g*5*8  40  8.801043e+12
# 1865 2022-07-01  매출  37806     1   BX  140g*5*8  40  8.801043e+12
# 1866 2022-07-01  매출  37836     1   BX  140g*5*8  40  8.801043e+12
# 1867 2022-07-01  매출  37925     2   BX  140g*5*8  40  8.801043e+12
# 1868 2022-07-01  매출  38002     1   BX  140g*5*8  40  8.801043e+12
#
#                  상품명  Unnamed: 9  Unnamed: 10
# 0     농심]짜파게티 멀티<40>         NaN          NaN
# 1     농심]짜파게티 멀티<40>         NaN          NaN
# 2     농심]짜파게티 멀티<40>         NaN          NaN
# 3     농심]짜파게티 멀티<40>         NaN          NaN
# 4     농심]짜파게티 멀티<40>         NaN          NaN
# ...              ...         ...          ...
# 1864  농심]짜파게티 멀티<40>         NaN          NaN
# 1865  농심]짜파게티 멀티<40>         NaN          NaN
# 1866  농심]짜파게티 멀티<40>         NaN          NaN
# 1867  농심]짜파게티 멀티<40>         NaN          NaN
# 1868  농심]짜파게티 멀티<40>         NaN          NaN
#
# [1869 rows x 11 columns]
#             판매일  구분   우편번호  판매수량 옵션코드   규격  입수        상품 바코드  \
# 0    2021-01-04  매출  37544     1   BX  5*8  40  1.880105e+13
# 1    2021-01-04  매출  37817     1   BX  5*8  40  1.880105e+13
# 2    2021-01-04  매출  37888     1   BX  5*8  40  1.880105e+13
# 3    2021-01-05  매출  37815     1   BX  5*8  40  1.880105e+13
# 4    2021-01-05  매출  37921     1   BX  5*8  40  1.880105e+13
# ...         ...  ..    ...   ...  ...  ...  ..           ...
# 1543 2022-07-01  매출  37692     2   BX  5*8  40  1.880105e+13
# 1544 2022-07-01  매출  37827     5   BX  5*8  40  1.880105e+13
# 1545 2022-07-01  매출  37871     4   BX  5*8  40  1.880105e+13
# 1546 2022-07-01  매출  37917     2   BX  5*8  40  1.880105e+13
# 1547 2022-07-01  매출  50246     2   BX  5*8  40  1.880105e+13
#
#                     상품명  Unnamed: 9  Unnamed: 10
# 0     오뚜기]진라면매운멀티<120g>         NaN          NaN
# 1     오뚜기]진라면매운멀티<120g>         NaN          NaN
# 2     오뚜기]진라면매운멀티<120g>         NaN          NaN
# 3     오뚜기]진라면매운멀티<120g>         NaN          NaN
# 4     오뚜기]진라면매운멀티<120g>         NaN          NaN
# ...                 ...         ...          ...
# 1543  오뚜기]진라면매운멀티<120g>         NaN          NaN
# 1544  오뚜기]진라면매운멀티<120g>         NaN          NaN
# 1545  오뚜기]진라면매운멀티<120g>         NaN          NaN
# 1546  오뚜기]진라면매운멀티<120g>         NaN          NaN
# 1547  오뚜기]진라면매운멀티<120g>         NaN          NaN
#
# [1548 rows x 11 columns]
#             판매일  구분     우편번호  판매수량 옵션코드       규격  입수        상품 바코드  \
# 0    2021-01-04  매출    37544     1   BX  120*5*8  40  8.801043e+12
# 1    2021-01-04  매출  377-65      1   BX  120*5*8  40  8.801043e+12
# 2    2021-01-04  매출    37772     1   BX  120*5*8  40  8.801043e+12
# 3    2021-01-04  매출    37817     1   BX  120*5*8  40  8.801043e+12
# 4    2021-01-04  매출    37830     1   BX  120*5*8  40  8.801043e+12
# ...         ...  ..      ...   ...  ...      ...  ..           ...
# 1364 2022-07-01  매출    37592     1   BX  120*5*8  40  8.801043e+12
# 1365 2022-07-01  매출    37694     1   BX  120*5*8  40  8.801043e+12
# 1366 2022-07-01  매출    37815     1   BX  120*5*8  40  8.801043e+12
# 1367 2022-07-01  매출    37928     1   BX  120*5*8  40  8.801043e+12
# 1368 2022-07-01  매출    38002     1   BX  120*5*8  40  8.801043e+12
#
#                   상품명  Unnamed: 9  Unnamed: 10
# 0     농심]너구리 얼큰멀티<40>         NaN          NaN
# 1     농심]너구리 얼큰멀티<40>         NaN          NaN
# 2     농심]너구리 얼큰멀티<40>         NaN          NaN
# 3     농심]너구리 얼큰멀티<40>         NaN          NaN
# 4     농심]너구리 얼큰멀티<40>         NaN          NaN
# ...               ...         ...          ...
# 1364  농심]너구리 얼큰멀티<40>         NaN          NaN
# 1365  농심]너구리 얼큰멀티<40>         NaN          NaN
# 1366  농심]너구리 얼큰멀티<40>         NaN          NaN
# 1367  농심]너구리 얼큰멀티<40>         NaN          NaN
# 1368  농심]너구리 얼큰멀티<40>         NaN          NaN
#
# [1369 rows x 11 columns]

# %%
import pandas as pd

# 여러 데이터프레임을 리스트로 관리
dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]

# 반복문을 사용하여 각 데이터프레임에 대해 전처리 작업 수행
merged_dfs = []  # 전처리된 결과를 저장할 리스트

for df in dfs:
    df_true = df[df['구분'] == '매출'][['판매일', '판매수량']]
    df_false = df[df['구분'] == '반품'][['판매일', '판매수량']]

    df_sum_by_date_0 = df_true.groupby('판매일').sum().reset_index()
    df_sum_by_date_1 = df_false.groupby('판매일').sum().reset_index()

    merged_df = pd.merge(df_sum_by_date_0, df_sum_by_date_1, on='판매일', suffixes=('_df0', '_df1'), how='left')
    merged_df.fillna(0, inplace=True)
    merged_df['최종 판매수량'] = merged_df['판매수량_df0'] - merged_df['판매수량_df1']

    merged_dfs.append(merged_df)

# merged_dfs 리스트에 각 데이터프레임의 전처리 결과가 저장됨

# %%
merged_dfs
# Out:
# [           판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04       258       0.0    258.0
#  1   2021-01-05       103       0.0    103.0
#  2   2021-01-06       102      12.0     90.0
#  3   2021-01-07       170       0.0    170.0
#  4   2021-01-08       179       0.0    179.0
#  ..         ...       ...       ...      ...
#  375 2022-06-27       171       0.0    171.0
#  376 2022-06-28        59       0.0     59.0
#  377 2022-06-29       504       0.0    504.0
#  378 2022-06-30       114       0.0    114.0
#  379 2022-07-01       418       0.0    418.0
#
#  [380 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04       108       0.0    108.0
#  1   2021-01-05        55       0.0     55.0
#  2   2021-01-06        31       0.0     31.0
#  3   2021-01-07         9       0.0      9.0
#  4   2021-01-08        57       0.0     57.0
#  ..         ...       ...       ...      ...
#  357 2022-06-27        13       0.0     13.0
#  358 2022-06-28         3       0.0      3.0
#  359 2022-06-29        90       0.0     90.0
#  360 2022-06-30        50       0.0     50.0
#  361 2022-07-01        86       0.0     86.0
#
#  [362 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04         4       0.0      4.0
#  1   2021-01-05        14       0.0     14.0
#  2   2021-01-07        20       0.0     20.0
#  3   2021-01-08        10       0.0     10.0
#  4   2021-01-11         9       0.0      9.0
#  ..         ...       ...       ...      ...
#  314 2022-06-24        14       0.0     14.0
#  315 2022-06-27        32       0.0     32.0
#  316 2022-06-28        13       0.0     13.0
#  317 2022-06-30        19       0.0     19.0
#  318 2022-07-01        37       0.0     37.0
#
#  [319 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04         9       0.0      9.0
#  1   2021-01-05         9       0.0      9.0
#  2   2021-01-06        12       0.0     12.0
#  3   2021-01-08         7       0.0      7.0
#  4   2021-01-11        19       0.0     19.0
#  ..         ...       ...       ...      ...
#  350 2022-06-27         6       0.0      6.0
#  351 2022-06-28         4       0.0      4.0
#  352 2022-06-29        14       0.0     14.0
#  353 2022-06-30         7       0.0      7.0
#  354 2022-07-01        16       0.0     16.0
#
#  [355 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04        36       0.0     36.0
#  1   2021-01-05        12       0.0     12.0
#  2   2021-01-06        12       0.0     12.0
#  3   2021-01-07        36       0.0     36.0
#  4   2021-01-08        48       0.0     48.0
#  ..         ...       ...       ...      ...
#  332 2022-06-27        36       0.0     36.0
#  333 2022-06-28        96       0.0     96.0
#  334 2022-06-29        24       0.0     24.0
#  335 2022-06-30        24       0.0     24.0
#  336 2022-07-01       108       0.0    108.0
#
#  [337 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04        20       0.0     20.0
#  1   2021-01-05         7       0.0      7.0
#  2   2021-01-06         5       0.0      5.0
#  3   2021-01-07         9       0.0      9.0
#  4   2021-01-08         7       0.0      7.0
#  ..         ...       ...       ...      ...
#  373 2022-06-27         8       0.0      8.0
#  374 2022-06-28         4       0.0      4.0
#  375 2022-06-29        19       0.0     19.0
#  376 2022-06-30        11       0.0     11.0
#  377 2022-07-01        21       0.0     21.0
#
#  [378 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04        14       2.0     12.0
#  1   2021-01-05         6       0.0      6.0
#  2   2021-01-06        18       3.0     15.0
#  3   2021-01-07         3       0.0      3.0
#  4   2021-01-08         4       0.0      4.0
#  ..         ...       ...       ...      ...
#  358 2022-06-27         9       0.0      9.0
#  359 2022-06-28         8       0.0      8.0
#  360 2022-06-29         6       0.0      6.0
#  361 2022-06-30         5       0.0      5.0
#  362 2022-07-01        24       0.0     24.0
#
#  [363 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04         7       0.0      7.0
#  1   2021-01-05         7       0.0      7.0
#  2   2021-01-06         5       0.0      5.0
#  3   2021-01-07         5       0.0      5.0
#  4   2021-01-08         1       0.0      1.0
#  ..         ...       ...       ...      ...
#  362 2022-06-24         7       0.0      7.0
#  363 2022-06-27         6       0.0      6.0
#  364 2022-06-29         8       0.0      8.0
#  365 2022-06-30         3       0.0      3.0
#  366 2022-07-01        10       0.0     10.0
#
#  [367 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04         3       0.0      3.0
#  1   2021-01-05         2       0.0      2.0
#  2   2021-01-06         1       0.0      1.0
#  3   2021-01-07         5       0.0      5.0
#  4   2021-01-08         4       0.0      4.0
#  ..         ...       ...       ...      ...
#  358 2022-06-27         6       0.0      6.0
#  359 2022-06-28         3       0.0      3.0
#  360 2022-06-29         3       0.0      3.0
#  361 2022-06-30         2       0.0      2.0
#  362 2022-07-01        17       0.0     17.0
#
#  [363 rows x 4 columns],
#             판매일  판매수량_df0  판매수량_df1  최종 판매수량
#  0   2021-01-04         7       0.0      7.0
#  1   2021-01-05         6       0.0      6.0
#  2   2021-01-06         4       0.0      4.0
#  3   2021-01-07         1       0.0      1.0
#  4   2021-01-08         8       0.0      8.0
#  ..         ...       ...       ...      ...
#  358 2022-06-27         3       0.0      3.0
#  359 2022-06-28         3       0.0      3.0
#  360 2022-06-29         1       0.0      1.0
#  361 2022-06-30         1       0.0      1.0
#  362 2022-07-01         7       0.0      7.0
#
#  [363 rows x 4 columns]]
